# %%
import pandas as pd
df = pd.read_csv('C:/Users/rlumbao/Downloads/socmed.csv')
print(df)
# Out:
#                                 CustomerID  \
# 0     08a911a3-65e6-4f5d-a6a1-ae7ddcbe28a2
# 1     efdfdfc9-5dbb-4478-911a-101a390a0285
# 2     3e44871b-f56c-4576-b1ca-d1dc999e2166
# 3     aa5eea4b-c948-41f4-9285-229a470002aa
# 4     481bcc62-9dcb-4766-bbdd-79f5554d73f8
# ...                                    ...
# 2534  8d8fe8bd-2009-4a15-be37-83dba3cef447
# 2535  1756838b-8368-4852-b4a5-32a23643a3dd
# 2536  eb8bb3ce-e182-4a9c-8084-c55c738815e1
# 2537  a5d08a95-9dba-4e3d-b997-1cfdde6a89ef
# 2538  f8146100-569d-4cda-9d64-88c6ad98de5f
#
#                              InteractionID InteractionDate   Platform  \
# 0     a83fa04c-f109-4f24-8ce1-2078154f6a1c      05/24/2024  Instagram
# 1     28a69c4b-a2e4-4c74-a130-1132d7733fdf      11/01/2023  Instagram
# 2     0c409883-8396-48e4-83fb-887329848696      12/18/2023  Instagram
# 3     4034dadf-6541-40d6-a7f0-16b20a009c04      11/15/2023  Instagram
# 4     785b7854-4548-4251-83f2-a25da78bfe40      05/28/2024    Twitter
# ...                                    ...             ...        ...
# 2534  2212803c-4a00-4263-bae5-aaaff6d6bdb1      08/30/2023  Instagram
# 2535  2f50ca57-f930-4d3e-ae08-9f3b26c7f148      06/16/2024   Facebook
# 2536  ee2c3d14-248c-48b0-aa80-4ea97e449bf8      12/22/2023  Instagram
# 2537  e77a8713-fdc7-4f71-85f8-9cd88cca0c42      11/01/2023    Twitter
# 2538  454a0b90-d1bb-437d-ad50-ef01821fbf0a      06/20/2024  Instagram
#
#      InteractionType Sentiment
# 0            Comment   Neutral
# 1               Like   Neutral
# 2            Comment  Positive
# 3              Share  Positive
# 4               Like  Positive
# ...              ...       ...
# 2534            Like   Neutral
# 2535            Like   Neutral
# 2536         Comment  Negative
# 2537           Share  Positive
# 2538            Like   Neutral
#
# [2539 rows x 6 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('C:/Users/rlumbao/Downloads/socmed.csv')
sentiment_counts = df['Sentiment'].value_counts()
ax = sentiment_counts.plot(kind='bar', figsize=(8, 6), color='skyblue')
plt.title('Sentiment Distribution')
plt.xlabel('Sentiment')
plt.ylabel('Count')
plt.xticks(rotation=0)
for i, value in enumerate(sentiment_counts):
    ax.text(i, value + 10, str(value), ha='center', va='bottom')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('C:/Users/rlumbao/Downloads/socmed.csv')
platform_sentiment_counts = df.groupby(['Platform', 'Sentiment']).size().unstack(fill_value=0)
ax = platform_sentiment_counts.plot(kind='bar', stacked=False, figsize=(10, 6), color=['skyblue', 'lightgreen', 'salmon'])
plt.title('Sentiment Distribution Across Platforms')
plt.xlabel('Platform')
plt.ylabel('Number of Interactions')
plt.xticks(rotation=45)  # Rotate platform labels for better readability
plt.legend(title='Sentiment', bbox_to_anchor=(1, 1), loc='upper left')  # Position the legend outside the plot
plt.grid(True)

plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('C:/Users/rlumbao/Downloads/socmed.csv')
ax = sns.countplot(data=df, x='InteractionType', hue='InteractionType', dodge=False, palette='pastel', legend=False)
for bar in ax.patches:
    bar_height = bar.get_height()
    ax.text(
        bar.get_x() + bar.get_width() / 2,
        bar_height + 0.5,
        f'{int(bar_height)}',
        ha='center', va='bottom', fontsize=10, color='black'
    )
plt.title('Customer Interaction Type Breakdown', fontsize=16)
plt.xlabel('InteractionType', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
