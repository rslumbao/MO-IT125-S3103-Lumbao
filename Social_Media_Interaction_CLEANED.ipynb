# %%
import pandas as pd
data = "C:/Users/rlumbao/Downloads/social_media.csv"
df = pd.read_csv(data)
print(df)
# Out:
#                                 CustomerID  \
# 0     2dcb9523-356b-40b2-a67b-1f27797de261
# 1     e12c37b3-7d4d-472f-9fd8-0df2cb3001aa
# 2     08a911a3-65e6-4f5d-a6a1-ae7ddcbe28a2
# 3     efdfdfc9-5dbb-4478-911a-101a390a0285
# 4     ca1e90f6-0e5f-492e-ab92-252ff540da18
# ...                                    ...
# 3195  8d8fe8bd-2009-4a15-be37-83dba3cef447
# 3196  1756838b-8368-4852-b4a5-32a23643a3dd
# 3197  eb8bb3ce-e182-4a9c-8084-c55c738815e1
# 3198  a5d08a95-9dba-4e3d-b997-1cfdde6a89ef
# 3199  f8146100-569d-4cda-9d64-88c6ad98de5f
#
#                              InteractionID InteractionDate   Platform  \
# 0     e5d15761-d0a7-4329-89e3-79a892c56097      2023-07-11        NaN
# 1     02f9f376-70ae-4fcd-9070-1db977939948      2023-07-06    Twitter
# 2     a83fa04c-f109-4f24-8ce1-2078154f6a1c      2024-05-24  Instagram
# 3     28a69c4b-a2e4-4c74-a130-1132d7733fdf      2023-11-01  Instagram
# 4     d9d1c6f8-5e15-4738-b52b-13c2982420cc      2023-07-08  Instagram
# ...

# %%
import pandas as pd
data = "C:/Users/rlumbao/Downloads/social_media.csv"
df = pd.read_csv(data)
print(df.head())
print(df['InteractionDate'].dtype)
df['InteractionDate'] = pd.to_datetime(df['InteractionDate'], errors='coerce')
if df['InteractionDate'].isnull().any():
    print("There were issues converting some dates.")
    df['InteractionDate'] = df['InteractionDate'].dt.strftime('%m/%d/%Y')
    print(df)
# Out:
#                              CustomerID                         InteractionID  \
# 0  2dcb9523-356b-40b2-a67b-1f27797de261  e5d15761-d0a7-4329-89e3-79a892c56097
# 1  e12c37b3-7d4d-472f-9fd8-0df2cb3001aa  02f9f376-70ae-4fcd-9070-1db977939948
# 2  08a911a3-65e6-4f5d-a6a1-ae7ddcbe28a2  a83fa04c-f109-4f24-8ce1-2078154f6a1c
# 3  efdfdfc9-5dbb-4478-911a-101a390a0285  28a69c4b-a2e4-4c74-a130-1132d7733fdf
# 4  ca1e90f6-0e5f-492e-ab92-252ff540da18  d9d1c6f8-5e15-4738-b52b-13c2982420cc
#
#   InteractionDate   Platform InteractionType Sentiment
# 0      2023-07-11        NaN         Comment       NaN
# 1      2023-07-06    Twitter           Share       NaN
# 2      2024-05-24  Instagram         Comment   Neutral
# 3      2023-11-01  Instagram            Like   Neutral
# 4      2023-07-08  Instagram            Like       NaN
# object
# There were issues converting some dates.
#                                 CustomerID  \
# 0     2dcb9523-356b-40b2-a67b-1f27797de261
# ...

# %%
import pandas as pd
data = "C:/Users/rlumbao/Downloads/social_media.csv"
df = pd.read_csv(data)
print(df.head())
print(df['InteractionDate'].dtype)
df['InteractionDate'] = pd.to_datetime(df['InteractionDate'], errors='coerce')
if df['InteractionDate'].isnull().any():
    print("There were issues converting some dates.")
    df['InteractionDate'] = df['InteractionDate'].dt.strftime('%m/%d/%Y')
if df['InteractionDate'].isnull().any():
    problematic_dates = df[df['InteractionDate'].isnull()]['InteractionDate']
    print("Problematic dates:")
    print(problematic_dates)
# Out:
#                              CustomerID                         InteractionID  \
# 0  2dcb9523-356b-40b2-a67b-1f27797de261  e5d15761-d0a7-4329-89e3-79a892c56097
# 1  e12c37b3-7d4d-472f-9fd8-0df2cb3001aa  02f9f376-70ae-4fcd-9070-1db977939948
# 2  08a911a3-65e6-4f5d-a6a1-ae7ddcbe28a2  a83fa04c-f109-4f24-8ce1-2078154f6a1c
# 3  efdfdfc9-5dbb-4478-911a-101a390a0285  28a69c4b-a2e4-4c74-a130-1132d7733fdf
# 4  ca1e90f6-0e5f-492e-ab92-252ff540da18  d9d1c6f8-5e15-4738-b52b-13c2982420cc
#
#   InteractionDate   Platform InteractionType Sentiment
# 0      2023-07-11        NaN         Comment       NaN
# 1      2023-07-06    Twitter           Share       NaN
# 2      2024-05-24  Instagram         Comment   Neutral
# 3      2023-11-01  Instagram            Like   Neutral
# 4      2023-07-08  Instagram            Like       NaN
# object
# There were issues converting some dates.
# Problematic dates:
# 20      NaN
# 23      NaN
# 25      NaN
# 26      NaN
# 62      NaN
#        ...
# 3017    NaN
# ...

# %%
import pandas as pd
data = "C:/Users/rlumbao/Downloads/social_media.csv"
df = pd.read_csv(data)
df['InteractionDate'] = pd.to_datetime(df['InteractionDate'], errors='coerce')
df['formatted_date'] = df['InteractionDate'].dt.strftime('%m/%d/%Y')
print(df[['InteractionDate', 'formatted_date']].head())
# Out:
#   InteractionDate formatted_date
# 0      2023-07-11     07/11/2023
# 1      2023-07-06     07/06/2023
# 2      2024-05-24     05/24/2024
# 3      2023-11-01     11/01/2023
# 4      2023-07-08     07/08/2023

# %%
import pandas as pd
data = "C:/Users/rlumbao/Downloads/social_media.csv"
df = pd.read_csv(data)
df['InteractionDate'] = pd.to_datetime(df['InteractionDate'], errors='coerce')
df['formatted_date'] = df['InteractionDate'].dt.strftime('%m/%d/%Y')
print(df[['InteractionDate', 'formatted_date']].head(3200))
invalid_dates = df[df['InteractionDate'].isna()]
print(invalid_dates)
# Out:
#      InteractionDate formatted_date
# 0         2023-07-11     07/11/2023
# 1         2023-07-06     07/06/2023
# 2         2024-05-24     05/24/2024
# 3         2023-11-01     11/01/2023
# 4         2023-07-08     07/08/2023
# ...              ...            ...
# 3195      2023-08-30     08/30/2023
# 3196      2024-06-16     06/16/2024
# 3197      2023-12-22     12/22/2023
# 3198      2023-11-01     11/01/2023
# 3199      2024-06-20     06/20/2024
#
# [3200 rows x 2 columns]
#                                 CustomerID  \
# 20    851911c8-6d3f-4a7f-b70c-9b93057d9f94
# 23    81d213e6-e289-482d-b2a9-326144b84d2c
# 25    2d1c8d1a-be1f-45a9-82d8-036f5e17d809
# 26    013c4cd9-1d0f-4004-8772-065ab426d105
# 62    b12c84ec-8291-4fa9-8688-b3a8e0bfbd1a
# ...                                    ...
# 3017  a44b6ca5-c73e-4f7a-919c-617931e33a29
# 3021  fd7e416c-1740-490d-b816-d909294eaa21
# 3040  c0c0ce5a-4539-4013-abca-d0a3e41b4e2a
# 3084  68afa4cc-e2d5-4150-b358-2e14e7508721
# ...

# %%
import pandas as pd
data = "C:/Users/rlumbao/Downloads/social_media.csv"
df = pd.read_csv(data)
df['InteractionDate'] = pd.to_datetime(df['InteractionDate'], errors='coerce')
df['formatted_date'] = df['InteractionDate'].dt.strftime('%m/%d/%Y')
print(df[['InteractionDate', 'formatted_date']].head(3200))
invalid_dates = df[df['InteractionDate'].isna()]
print(invalid_dates)
df['InteractionDate'] = pd.to_datetime(df['InteractionDate'], errors='coerce')
df['InteractionDate'] = df['InteractionDate'].dt.strftime('%m/%d/%Y')
print(df.head(50))
# Out:
#      InteractionDate formatted_date
# 0         2023-07-11     07/11/2023
# 1         2023-07-06     07/06/2023
# 2         2024-05-24     05/24/2024
# 3         2023-11-01     11/01/2023
# 4         2023-07-08     07/08/2023
# ...              ...            ...
# 3195      2023-08-30     08/30/2023
# 3196      2024-06-16     06/16/2024
# 3197      2023-12-22     12/22/2023
# 3198      2023-11-01     11/01/2023
# 3199      2024-06-20     06/20/2024
#
# [3200 rows x 2 columns]
#                                 CustomerID  \
# 20    851911c8-6d3f-4a7f-b70c-9b93057d9f94
# 23    81d213e6-e289-482d-b2a9-326144b84d2c
# 25    2d1c8d1a-be1f-45a9-82d8-036f5e17d809
# 26    013c4cd9-1d0f-4004-8772-065ab426d105
# 62    b12c84ec-8291-4fa9-8688-b3a8e0bfbd1a
# ...                                    ...
# 3017  a44b6ca5-c73e-4f7a-919c-617931e33a29
# 3021  fd7e416c-1740-490d-b816-d909294eaa21
# 3040  c0c0ce5a-4539-4013-abca-d0a3e41b4e2a
# 3084  68afa4cc-e2d5-4150-b358-2e14e7508721
# ...

# %%
import pandas as pd
data = "C:/Users/rlumbao/Downloads/social_media.csv"
df = pd.read_csv(data)
df['InteractionDate'] = pd.to_datetime(df['InteractionDate'], errors='coerce')
df['formatted_date'] = df['InteractionDate'].dt.strftime('%m/%d/%Y')
print(df[['InteractionDate', 'formatted_date']].head(3200))
invalid_dates = df[df['InteractionDate'].isna()]
print(invalid_dates)
df = df.dropna(subset=['InteractionDate'])
print(df.head(3200))
output_file = df.to_csv("C:/Users/rlumbao/Downloads/social_media_cleaned1", index = False)
# Out:
#      InteractionDate formatted_date
# 0         2023-07-11     07/11/2023
# 1         2023-07-06     07/06/2023
# 2         2024-05-24     05/24/2024
# 3         2023-11-01     11/01/2023
# 4         2023-07-08     07/08/2023
# ...              ...            ...
# 3195      2023-08-30     08/30/2023
# 3196      2024-06-16     06/16/2024
# 3197      2023-12-22     12/22/2023
# 3198      2023-11-01     11/01/2023
# 3199      2024-06-20     06/20/2024
#
# [3200 rows x 2 columns]
#                                 CustomerID  \
# 20    851911c8-6d3f-4a7f-b70c-9b93057d9f94
# 23    81d213e6-e289-482d-b2a9-326144b84d2c
# 25    2d1c8d1a-be1f-45a9-82d8-036f5e17d809
# 26    013c4cd9-1d0f-4004-8772-065ab426d105
# 62    b12c84ec-8291-4fa9-8688-b3a8e0bfbd1a
# ...                                    ...
# 3017  a44b6ca5-c73e-4f7a-919c-617931e33a29
# 3021  fd7e416c-1740-490d-b816-d909294eaa21
# 3040  c0c0ce5a-4539-4013-abca-d0a3e41b4e2a
# 3084  68afa4cc-e2d5-4150-b358-2e14e7508721
# ...

# %%
import pandas as pd
data = "C:/Users/rlumbao/Downloads/social_media.csv"
df = pd.read_csv(data)
df['InteractionDate'] = pd.to_datetime(df['InteractionDate'], errors='coerce')
df['formatted_date'] = df['InteractionDate'].dt.strftime('%m/%d/%Y')
print(df[['InteractionDate', 'formatted_date']].head(3200))
invalid_dates = df[df['InteractionDate'].isna()]
print(invalid_dates)
df = df.dropna(subset=['InteractionDate'])
output_file = df.to_csv("C:/Users/rlumbao/Downloads/social_media_cleaned.csv", index=False)
# Out:
#      InteractionDate formatted_date
# 0         2023-07-11     07/11/2023
# 1         2023-07-06     07/06/2023
# 2         2024-05-24     05/24/2024
# 3         2023-11-01     11/01/2023
# 4         2023-07-08     07/08/2023
# ...              ...            ...
# 3195      2023-08-30     08/30/2023
# 3196      2024-06-16     06/16/2024
# 3197      2023-12-22     12/22/2023
# 3198      2023-11-01     11/01/2023
# 3199      2024-06-20     06/20/2024
#
# [3200 rows x 2 columns]
#                                 CustomerID  \
# 20    851911c8-6d3f-4a7f-b70c-9b93057d9f94
# 23    81d213e6-e289-482d-b2a9-326144b84d2c
# 25    2d1c8d1a-be1f-45a9-82d8-036f5e17d809
# 26    013c4cd9-1d0f-4004-8772-065ab426d105
# 62    b12c84ec-8291-4fa9-8688-b3a8e0bfbd1a
# ...                                    ...
# 3017  a44b6ca5-c73e-4f7a-919c-617931e33a29
# 3021  fd7e416c-1740-490d-b816-d909294eaa21
# 3040  c0c0ce5a-4539-4013-abca-d0a3e41b4e2a
# 3084  68afa4cc-e2d5-4150-b358-2e14e7508721
# ...

# %%
import pandas as pd
data = "C:/Users/rlumbao/Downloads/social_media.csv"
df = pd.read_csv(data)
df['InteractionDate'] = pd.to_datetime(df['InteractionDate'], errors='coerce')
df['formatted_date'] = df['InteractionDate'].dt.strftime('%m/%d/%Y')
print(df[['InteractionDate', 'formatted_date']].head(3200))
invalid_dates = df[df['InteractionDate'].isna()]
print(invalid_dates)
df = df.dropna(subset=['InteractionDate'])
df = df.drop_duplicates()
print(df.head(3200)) 
output_file = df.to_csv("C:/Users/rlumbao/Downloads/social_media_cleaned.csv", index=False)
# Out:
#      InteractionDate formatted_date
# 0         2023-07-11     07/11/2023
# 1         2023-07-06     07/06/2023
# 2         2024-05-24     05/24/2024
# 3         2023-11-01     11/01/2023
# 4         2023-07-08     07/08/2023
# ...              ...            ...
# 3195      2023-08-30     08/30/2023
# 3196      2024-06-16     06/16/2024
# 3197      2023-12-22     12/22/2023
# 3198      2023-11-01     11/01/2023
# 3199      2024-06-20     06/20/2024
#
# [3200 rows x 2 columns]
#                                 CustomerID  \
# 20    851911c8-6d3f-4a7f-b70c-9b93057d9f94
# 23    81d213e6-e289-482d-b2a9-326144b84d2c
# 25    2d1c8d1a-be1f-45a9-82d8-036f5e17d809
# 26    013c4cd9-1d0f-4004-8772-065ab426d105
# 62    b12c84ec-8291-4fa9-8688-b3a8e0bfbd1a
# ...                                    ...
# 3017  a44b6ca5-c73e-4f7a-919c-617931e33a29
# 3021  fd7e416c-1740-490d-b816-d909294eaa21
# 3040  c0c0ce5a-4539-4013-abca-d0a3e41b4e2a
# 3084  68afa4cc-e2d5-4150-b358-2e14e7508721
# ...

# %%
import pandas as pd
data = "C:/Users/rlumbao/Downloads/social_media.csv"
df = pd.read_csv(data)
df['InteractionDate'] = pd.to_datetime(df['InteractionDate'], errors='coerce')
df['formatted_date'] = df['InteractionDate'].dt.strftime('%m/%d/%Y')
print(df[['InteractionDate', 'formatted_date']].head(3200))
invalid_dates = df[df['InteractionDate'].isna()]
print(invalid_dates)
df = df.dropna(subset=['InteractionDate'])
df = df.drop_duplicates()
df['Platform'] = df['Platform'].fillna(df['Platform'].mode()[0])
print("\nDataFrame after handling missing values:")
print(df.to_string())
# Out:
#      InteractionDate formatted_date
# 0         2023-07-11     07/11/2023
# 1         2023-07-06     07/06/2023
# 2         2024-05-24     05/24/2024
# 3         2023-11-01     11/01/2023
# 4         2023-07-08     07/08/2023
# ...              ...            ...
# 3195      2023-08-30     08/30/2023
# 3196      2024-06-16     06/16/2024
# 3197      2023-12-22     12/22/2023
# 3198      2023-11-01     11/01/2023
# 3199      2024-06-20     06/20/2024
#
# [3200 rows x 2 columns]
#                                 CustomerID  \
# 20    851911c8-6d3f-4a7f-b70c-9b93057d9f94
# 23    81d213e6-e289-482d-b2a9-326144b84d2c
# 25    2d1c8d1a-be1f-45a9-82d8-036f5e17d809
# 26    013c4cd9-1d0f-4004-8772-065ab426d105
# 62    b12c84ec-8291-4fa9-8688-b3a8e0bfbd1a
# ...                                    ...
# 3017  a44b6ca5-c73e-4f7a-919c-617931e33a29
# 3021  fd7e416c-1740-490d-b816-d909294eaa21
# 3040  c0c0ce5a-4539-4013-abca-d0a3e41b4e2a
# 3084  68afa4cc-e2d5-4150-b358-2e14e7508721
# ...

# %%
import pandas as pd
data = "C:/Users/rlumbao/Downloads/social_media.csv"
df = pd.read_csv(data)
df['InteractionDate'] = pd.to_datetime(df['InteractionDate'], errors='coerce')
df['formatted_date'] = df['InteractionDate'].dt.strftime('%m/%d/%Y')
print(df[['InteractionDate', 'formatted_date']].head(3200))
invalid_dates = df[df['InteractionDate'].isna()]
print(invalid_dates)
df = df.dropna(subset=['InteractionDate'])
df = df.drop_duplicates()
df['Platform'] = df['Platform'].fillna(df['Platform'].mode()[0])
df['Sentiment'] = df['Sentiment'].fillna(df['Sentiment'].mode()[0])
print("\nDataFrame after handling missing values:")
print(df.to_string())
# Out:
#      InteractionDate formatted_date
# 0         2023-07-11     07/11/2023
# 1         2023-07-06     07/06/2023
# 2         2024-05-24     05/24/2024
# 3         2023-11-01     11/01/2023
# 4         2023-07-08     07/08/2023
# ...              ...            ...
# 3195      2023-08-30     08/30/2023
# 3196      2024-06-16     06/16/2024
# 3197      2023-12-22     12/22/2023
# 3198      2023-11-01     11/01/2023
# 3199      2024-06-20     06/20/2024
#
# [3200 rows x 2 columns]
#                                 CustomerID  \
# 20    851911c8-6d3f-4a7f-b70c-9b93057d9f94
# 23    81d213e6-e289-482d-b2a9-326144b84d2c
# 25    2d1c8d1a-be1f-45a9-82d8-036f5e17d809
# 26    013c4cd9-1d0f-4004-8772-065ab426d105
# 62    b12c84ec-8291-4fa9-8688-b3a8e0bfbd1a
# ...                                    ...
# 3017  a44b6ca5-c73e-4f7a-919c-617931e33a29
# 3021  fd7e416c-1740-490d-b816-d909294eaa21
# 3040  c0c0ce5a-4539-4013-abca-d0a3e41b4e2a
# 3084  68afa4cc-e2d5-4150-b358-2e14e7508721
# ...

# %%
import pandas as pd
data = "C:/Users/rlumbao/Downloads/social_media.csv"
df = pd.read_csv(data)
df['InteractionDate'] = pd.to_datetime(df['InteractionDate'], errors='coerce')
df['formatted_date'] = df['InteractionDate'].dt.strftime('%m/%d/%Y')
print(df[['InteractionDate', 'formatted_date']].head(3200))
invalid_dates = df[df['InteractionDate'].isna()]
print(invalid_dates)
df = df.dropna(subset=['InteractionDate'])
df = df.drop_duplicates()
df['Platform'] = df['Platform'].fillna(df['Platform'].mode()[0])
df['Sentiment'] = df['Sentiment'].fillna(df['Sentiment'].mode()[0])
print("\nDataFrame after handling missing values:")
output_file = df.to_csv("C:/Users/rlumbao/Downloads/social_media_cleaned.csv", index=False)
# Out:
#      InteractionDate formatted_date
# 0         2023-07-11     07/11/2023
# 1         2023-07-06     07/06/2023
# 2         2024-05-24     05/24/2024
# 3         2023-11-01     11/01/2023
# 4         2023-07-08     07/08/2023
# ...              ...            ...
# 3195      2023-08-30     08/30/2023
# 3196      2024-06-16     06/16/2024
# 3197      2023-12-22     12/22/2023
# 3198      2023-11-01     11/01/2023
# 3199      2024-06-20     06/20/2024
#
# [3200 rows x 2 columns]
#                                 CustomerID  \
# 20    851911c8-6d3f-4a7f-b70c-9b93057d9f94
# 23    81d213e6-e289-482d-b2a9-326144b84d2c
# 25    2d1c8d1a-be1f-45a9-82d8-036f5e17d809
# 26    013c4cd9-1d0f-4004-8772-065ab426d105
# 62    b12c84ec-8291-4fa9-8688-b3a8e0bfbd1a
# ...                                    ...
# 3017  a44b6ca5-c73e-4f7a-919c-617931e33a29
# 3021  fd7e416c-1740-490d-b816-d909294eaa21
# 3040  c0c0ce5a-4539-4013-abca-d0a3e41b4e2a
# 3084  68afa4cc-e2d5-4150-b358-2e14e7508721
# ...
